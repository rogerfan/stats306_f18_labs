# %% [markdown]
# # Lab 4: Data Analysis

# %% [markdown]
# Today, we look at what people order at Chipotle. Some example questions we are interested in are:
# - How much do people spend on average at Chipotle?
# - Do people prefer bowls or burritos?
# - What percentage of people order drinks?
# - ...

# %% [markdown]
# Recall the following commands from `dplyr`:
#
# 1. `group_by`
# 2. `summarize`:  `df = df %>% group_by(groupvar) %>% summarize(newvar = mean(oldvar))`
# 3. `mutate`: `df = df %>% mutate(newvar = oldvar + sqrt(oldvar2))`
# 4. `filter`: `df = df %>% filter(compvar == 'something')`

# %%
# Setup and read in data
options(repr.plot.width=8, repr.plot.height=4)

library(dplyr)
library(ggplot2)
library(stringr)
df = read.csv("https://raw.githubusercontent.com/rogerfan/stats306_f18_labs/master/chipotle.csv", stringsAsFactors=F)
df$X = NULL

# %%
head(df)
# Out:
#   order_id quantity item_name
# 1 1        1        Chips and Fresh Tomato Salsa
# 2 1        1        Izze
# 3 1        1        Nantucket Nectar
# 4 1        1        Chips and Tomatillo-Green Chili Salsa
# 5 2        2        Chicken Bowl
# 6 3        1        Chicken Bowl
#   choice_description
# 1
# 2 [Clementine]
# 3 [Apple]
# 4
# 5 [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
# 6 [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sour Cream, Guacamole, Lettuce]]
#   item_price
# 1 $2.39
# 2 $3.39
# 3 $3.39
# 4 $2.39
# 5 $16.98
# 6 $10.98

# %% [markdown]
# ### Q1: What are the five most popular items?

# %%
df %>% group_by(item_name) %>% 
    summarize(itemsold = sum(quantity)) %>% 
    arrange(desc(itemsold)) %>% top_n(5)

df %>% group_by(item_name) %>% 
    summarize(itemsold = n()) %>% 
    arrange(desc(itemsold)) %>% top_n(5)
# Out:
# Selecting by itemsold
#   item_name           itemsold
# 1 Chicken Bowl        761
# 2 Chicken Burrito     591
# 3 Chips and Guacamole 506
# 4 Steak Burrito       386
# 5 Canned Soft Drink   351
# Selecting by itemsold
#   item_name           itemsold
# 1 Chicken Bowl        726
# 2 Chicken Burrito     553
# 3 Chips and Guacamole 479
# 4 Steak Burrito       368
# 5 Canned Soft Drink   301

# %% [markdown]
# ### Q2: `item_price` is currently a string. Remove the dollar sign and convert it to a numerical variable
#
# Hint: Consider the functions `str_replace` and `as.numeric`. Note that to replace dollar signs in the string you will need to use `'\\$'` in `str_replace`.

# %%
df = df %>% mutate(item_price = as.numeric(str_replace(item_price, '\\$', '')))
head(df)
# Out:
#   order_id quantity item_name
# 1 1        1        Chips and Fresh Tomato Salsa
# 2 1        1        Izze
# 3 1        1        Nantucket Nectar
# 4 1        1        Chips and Tomatillo-Green Chili Salsa
# 5 2        2        Chicken Bowl
# 6 3        1        Chicken Bowl
#   choice_description
# 1
# 2 [Clementine]
# 3 [Apple]
# 4
# 5 [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
# 6 [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sour Cream, Guacamole, Lettuce]]
#   item_price
# 1  2.39
# 2  3.39
# 3  3.39
# 4  2.39
# 5 16.98
# 6 10.98

# %% [markdown]
# ### Q3: Construct a summary table by item type
#
# For each item type, the table should contain the total revenue, the number of items sold, and the max, mean, and minimum prices. Sort the table by items sold in decreasing order.
#
# I have done this for you, and my solution is:

# %%
pricetable = df %>% group_by(item_name) %>% 
    summarize(revenue = sum(item_price), 
              itemsold = n(),
              meanprice = mean(item_price),
              maxprice = max(item_price),                       
              minprice = min(item_price)) %>% 
    arrange(desc(itemsold))
head(pricetable)
# Out:
#   item_name           revenue itemsold meanprice maxprice minprice
# 1 Chicken Bowl        7342.73 726      10.113953 32.94    8.19
# 2 Chicken Burrito     5575.82 553      10.082857 35.00    8.19
# 3 Chips and Guacamole 2201.04 479       4.595073 17.80    3.89
# 4 Steak Burrito       3851.43 368      10.465842 27.75    8.69
# 5 Canned Soft Drink    438.75 301       1.457641  5.00    1.25
# 6 Chips                494.34 211       2.342844  6.45    1.99

# %% [markdown]
# Does anything look strange about this summary?

# %% [markdown]
# ### Q4: What is the issue? Can you figure out the mistake in the code above?
#
# Hint: Look carefully some problematic rows.

# %%
df %>% filter(item_price > 30)
# Out:
#   order_id quantity item_name
# 1  178      3       Chicken Bowl
# 2  511      4       Chicken Burrito
# 3 1398      3       Carnitas Bowl
# 4 1443     15       Chips and Fresh Tomato Salsa
# 5 1443      3       Veggie Burrito
# 6 1443      4       Chicken Burrito
#   choice_description
# 1 [[Fresh Tomato Salsa (Mild), Tomatillo-Green Chili Salsa (Medium), Roasted Chili Corn Salsa (Medium)], [Black Beans, Rice, Fajita Veggies, Cheese, Guacamole, Lettuce]]
# 2 [Fresh Tomato Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Lettuce]]
# 3 [Roasted Chili Corn Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]
# 4
# 5 [Fresh Tomato Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Sour Cream, Guacamole]]
# 6 [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream]]
#   item_price
# 1 32.94
# 2 35.00
# 3 35.25
# 4 44.25
# 5 33.75
# 6 35.00

# %% [markdown]
# ### How would you fix the code in Q3?

# %%
pricetable = df %>% group_by(item_name) %>% 
    summarize(revenue = sum(item_price), 
              itemsold = sum(quantity),
              meanprice = revenue/itemsold,
              maxprice = max(item_price/quantity),                       
              minprice = min(item_price/quantity)) %>% 
    arrange(desc(itemsold))
head(pricetable)
# Out:
#   item_name           revenue itemsold meanprice maxprice minprice
# 1 Chicken Bowl        7342.73 761      9.648791  11.25    8.19
# 2 Chicken Burrito     5575.82 591      9.434552  11.25    8.19
# 3 Chips and Guacamole 2201.04 506      4.349881   4.45    3.89
# 4 Steak Burrito       3851.43 386      9.977798  11.75    8.69
# 5 Canned Soft Drink    438.75 351      1.250000   1.25    1.25
# 6 Chips                494.34 230      2.149304   2.15    1.99

# %% [markdown]
# ### Q4: Calculate the total price for each order. Plot a histogram of order prices.

# %%
totalprice = df %>% group_by(order_id) %>% summarize(tprice = sum(item_price))
head(totalprice)
# Out:
#   order_id tprice
# 1 1        11.56
# 2 2        16.98
# 3 3        12.67
# 4 4        21.00
# 5 5        13.70
# 6 6        17.50

# %%
ggplot(totalprice, aes(x=tprice)) + geom_histogram()
# Out:
# `stat_bin()` using `bins = 30`. Pick better value with `binwidth`.
# plot without title

# %% [markdown]
# Note how extreme outliers can make it difficult to interpret plots.

# %% [markdown]
# ### Q5: Change the plot in Q4 such that we look only at orders with prices below 40. Try different binwidths to see if your interpretations change.

# %%
totalprice_lt40 = totalprice %>% filter(tprice < 40)

# %%
ggplot(totalprice_lt40, aes(x=tprice)) + geom_histogram(binwidth=2)
# Out:
# plot without title

# %% [markdown]
# How do your spending habits at Chipotle compare to those who are in the dataset?

# %% [markdown]
# ### Q6: Are bowls, burritos, or tacos more popular? Create a bar plot of amount sold of each.
#
# To extract whether an item is a bowl, burrito, or taco, you can use the following code:

# %%
df = df %>% mutate(type = case_when(grepl("Bowl", item_name) ~ "Bowl",
                                    grepl("Burrito", item_name) ~ "Burrito",
                                    grepl("Tacos", item_name) ~ "Tacos",
                                    TRUE ~ "neither"))
bowburtable = df %>% filter(type != "neither") 
head(bowburtable)
# Out:
#   order_id quantity item_name
# 1 2        2        Chicken Bowl
# 2 3        1        Chicken Bowl
# 3 4        1        Steak Burrito
# 4 4        1        Steak Soft Tacos
# 5 5        1        Steak Burrito
# 6 6        1        Chicken Crispy Tacos
#   choice_description
# 1 [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
# 2 [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sour Cream, Guacamole, Lettuce]]
# 3 [Tomatillo Red Chili Salsa, [Fajita Vegetables, Black Beans, Pinto Beans, Cheese, Sour Cream, Guacamole, Lettuce]]
# 4 [Tomatillo Green Chili Salsa, [Pinto Beans, Cheese, Sour Cream, Lettuce]]
# 5 [Fresh Tomato Salsa, [Rice, Black Beans, Pinto Beans, Cheese, Sour Cream, Lettuce]]
# 6 [Roasted Chili Corn Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Sour Cream]]
#   item_price type
# 1 16.98      Bowl
# 2 10.98      Bowl
# 3 11.75      Burrito
# 4  9.25      Tacos
# 5  9.25      Burrito
# 6  8.75      Tacos

# %%
ggplot(bowburtable, aes(x=type)) + geom_bar(aes(weight=quantity))
# Out:
# plot without title

# %% [markdown]
# ### What about the different fillings (Chicken, Steak, Barbacoa, Carnitas, Veggie)? Color the above bar chart by type of filling.

# %%
df = df %>% mutate(filling = case_when(grepl("Chicken", item_name) ~ "Chicken",
                                    grepl("Steak", item_name) ~ "Steak",
                                    grepl("Barbacoa", item_name) ~ "Barbacoa",
                                    grepl("Carnitas", item_name) ~ "Carnitas",
                                    grepl("Veggie", item_name) ~ "Veggie",
                                    TRUE ~ "other"))
head(df)
bowburtable = df %>% filter(filling != 'other', type != 'neither') 
head(bowburtable)
# Out:
#   order_id quantity item_name
# 1 1        1        Chips and Fresh Tomato Salsa
# 2 1        1        Izze
# 3 1        1        Nantucket Nectar
# 4 1        1        Chips and Tomatillo-Green Chili Salsa
# 5 2        2        Chicken Bowl
# 6 3        1        Chicken Bowl
#   choice_description
# 1
# 2 [Clementine]
# 3 [Apple]
# 4
# 5 [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
# 6 [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sour Cream, Guacamole, Lettuce]]
#   item_price type    filling
# 1  2.39      neither other
# 2  3.39      neither other
# 3  3.39      neither other
# 4  2.39      neither other
# 5 16.98      Bowl    Chicken
# 6 10.98      Bowl    Chicken
#   order_id quantity item_name
# 1 2        2        Chicken Bowl
# 2 3        1        Chicken Bowl
# 3 4        1        Steak Burrito
# 4 4        1        Steak Soft Tacos
# 5 5        1        Steak Burrito
# 6 6        1        Chicken Crispy Tacos
#   choice_description
# 1 [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
# 2 [Fresh Tomato Salsa (Mild), [Rice, Cheese, Sour Cream, Guacamole, Lettuce]]
# 3 [Tomatillo Red Chili Salsa, [Fajita Vegetables, Black Beans, Pinto Beans, Cheese, Sour Cream, Guacamole, Lettuce]]
# 4 [Tomatillo Green Chili Salsa, [Pinto Beans, Cheese, Sour Cream, Lettuce]]
# 5 [Fresh Tomato Salsa, [Rice, Black Beans, Pinto Beans, Cheese, Sour Cream, Lettuce]]
# 6 [Roasted Chili Corn Salsa, [Fajita Vegetables, Rice, Black Beans, Cheese, Sour Cream]]
#   item_price type    filling
# 1 16.98      Bowl    Chicken
# 2 10.98      Bowl    Chicken
# 3 11.75      Burrito Steak
# 4  9.25      Tacos   Steak
# 5  9.25      Burrito Steak
# 6  8.75      Tacos   Chicken

# %%
ggplot(bowburtable, aes(x=type, fill=filling)) + geom_bar(aes(weight=quantity))
# Out:
# plot without title

# %% [markdown]
# ### Is there a modification you can make to the default bar chart to compare proportion of fillings across order types more easily?

# %%
ggplot(bowburtable, aes(x=type, fill=filling)) + geom_bar(aes(weight=quantity), position='fill')
# Out:
# plot without title

# %% [markdown]
# ### Q7: How many order contain at least one drink of any kind? How many don't have a drink? Create a bar plot.

# %%
unique(df$item_name)
# Out:
#  [1] "Chips and Fresh Tomato Salsa"
#  [2] "Izze"
#  [3] "Nantucket Nectar"
#  [4] "Chips and Tomatillo-Green Chili Salsa"
#  [5] "Chicken Bowl"
#  [6] "Side of Chips"
#  [7] "Steak Burrito"
#  [8] "Steak Soft Tacos"
#  [9] "Chips and Guacamole"
# [10] "Chicken Crispy Tacos"
# [11] "Chicken Soft Tacos"
# [12] "Chicken Burrito"
# [13] "Canned Soda"
# [14] "Barbacoa Burrito"
# [15] "Carnitas Burrito"
# [16] "Carnitas Bowl"
# [17] "Bottled Water"
# [18] "Chips and Tomatillo Green Chili Salsa"
# [19] "Barbacoa Bowl"
# [20] "Chips"
# [21] "Chicken Salad Bowl"
# [22] "Steak Bowl"
# [23] "Barbacoa Soft Tacos"
# [24] "Veggie Burrito"
# [25] "Veggie Bowl"
# [26] "Steak Crispy Tacos"
# [27] "Chips and Tomatillo Red Chili Salsa"
# [28] "Barbacoa Crispy Tacos"
# [29] "Veggie Salad Bowl"
# [30] "Chips and Roasted Chili-Corn Salsa"
# [31] "Chips and Roasted Chili Corn Salsa"
# [32] "Carnitas Soft Tacos"
# [33] "Chicken Salad"
# [34] "Canned Soft Drink"
# [35] "Steak Salad Bowl"
# [36] "6 Pack Soft Drink"
# [37] "Chips and Tomatillo-Red Chili Salsa"
# [38] "Bowl"
# [39] "Burrito"
# [40] "Crispy Tacos"
# [41] "Carnitas Crispy Tacos"
# [42] "Steak Salad"
# [43] "Chips and Mild Fresh Tomato Salsa"
# [44] "Veggie Soft Tacos"
# [45] "Carnitas Salad Bowl"
# [46] "Barbacoa Salad Bowl"
# [47] "Salad"
# [48] "Veggie Crispy Tacos"
# [49] "Veggie Salad"
# [50] "Carnitas Salad"

# %%
grepl('chick|barb', 'steak')
# Out:
# [1] FALSE

# %% [markdown]
# ### Bonus Question: Suppose non-drink items have a 20% profit margin and drinks have a 50% profit margin. What percentage of the total profit comes from drinks?
